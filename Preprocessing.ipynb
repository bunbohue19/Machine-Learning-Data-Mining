# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("data/original_data.csv")

# j = 0
# for i in df.columns:
#     plt.hist(df[i])
#     plt.title(i)
#     print(j)
#     j += 1    
#     plt.show()

# %%
def split(df, ratio):
    new_df = df.sample(frac = 1)
    idx = int(len(new_df) * ratio)
    X_train = new_df.iloc[:idx, :-1]
    y_train = new_df.iloc[:idx, -1]
    X_test = new_df.iloc[idx:, :-1]
    y_test = new_df.iloc[idx:, -1]
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split(df, ratio=0.995)

X_train.to_csv('data/train.csv')
y_train.to_csv('data/y_train.csv')
X_test.to_csv('data/test.csv')
y_test.to_csv('data/y_test.csv')

# %%
df_train = pd.read_csv('data/train.csv')

idxs = [i + 1 for i in range(len(df_train))]
df_train.insert(1, "id", idxs)
df_train.head()
# Out:
#    Unnamed: 0  id  Marital status  Application mode  Application order  \
# 0        2077   1               1                17                  1
# 1        4154   2               1                 1                  1
# 2        2050   3               1                 1                  1
# 3        2347   4               1                18                  1
# 4        2190   5               1                17                  1
#
#    Course  Daytime/evening attendance\t  Previous qualification  \
# 0    9500                             1                       1
# 1    9853                             1                       1
# 2    9238                             1                       1
# 3    9119                             1                       1
# 4     171                             1                       1
#
#    Previous qualification (grade)  Nacionality  ...  \
# 0                           145.0            1  ...
# ...

# %%
df_train.drop(columns=df_train.columns[0]).to_csv('data/train.csv')

# %%
df_test = pd.read_csv('data/test.csv')

idxs = [i + 1 for i in range(len(df_test))]
df_test.insert(1, "id", idxs)
df_test.head()
# Out:
#    Unnamed: 0  id  Marital status  Application mode  Application order  \
# 0        2231   1               1                 1                  1
# 1        4346   2               1                17                  2
# 2        3112   3               1                17                  4
# 3        2022   4               1                17                  4
# 4        2252   5               1                 7                  1
#
#    Course  Daytime/evening attendance\t  Previous qualification  \
# 0     171                             1                       1
# 1    9254                             1                       1
# 2    9254                             1                       1
# 3     171                             1                       1
# 4    9085                             1                      40
#
#    Previous qualification (grade)  Nacionality  ...  \
# 0                           124.0            1  ...
# ...

# %%
df_test.drop(columns=df_test.columns[0]).to_csv('data/test.csv')

# %%
df_y_train = pd.read_csv('data/y_train.csv')

idxs = [i + 1 for i in range(len(df_train))]
df_y_train.insert(1, "id", idxs)
df_y_train.head()
# Out:
#    Unnamed: 0  id    Target
# 0        2077   1  Graduate
# 1        4154   2   Dropout
# 2        2050   3  Graduate
# 3        2347   4  Graduate
# 4        2190   5  Enrolled

# %%
df_y_train.drop(columns=df_y_train.columns[0]).to_csv('data/y_train.csv')

# %%
df_y_test = pd.read_csv('data/y_test.csv')

idxs = [i + 1 for i in range(len(df_test))]
df_y_test.insert(1, "id", idxs)
df_y_test.head()
# Out:
#    Unnamed: 0  id   Target
# 0        2231   1  Dropout
# 1        4346   2  Dropout
# 2        3112   3  Dropout
# 3        2022   4  Dropout
# 4        2252   5  Dropout

# %%
df_y_test.drop(columns=df_y_test.columns[0]).to_csv('data/y_test.csv')
